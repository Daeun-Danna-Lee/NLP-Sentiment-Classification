# %% [markdown]
# <a href="https://colab.research.google.com/github/Daeun-Danna-Lee/NLP-Sentiment-Classification/blob/main/Movie_Review_Sentiment_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/e9t/nsmc.git
# Out:
# Cloning into 'nsmc'...
# remote: Enumerating objects: 14763, done.
# remote: Total 14763 (delta 0), reused 0 (delta 0), pack-reused 14763
# Receiving objects: 100% (14763/14763), 56.19 MiB | 19.44 MiB/s, done.
# Resolving deltas: 100% (1749/1749), done.
# Checking out files: 100% (14737/14737), done.

# %%
# !apt-get update
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev
# !pip3 install konlpy

# %%
# Out:
# env: JAVA_HOME="/usr/lib/jvm/java-8-openjdk-amd64"

# %%
import jpype

p = jpype.getDefaultJVMPath()
jpype.startJVM( p )

print(jpype.isJVMStarted())
# Out:
# True

# %%
# %%bash
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# pip3 install /tmp/mecab-python-0.996
# Out:
# mecab-ko is already installed
# mecab-ko-dic is already installed
# mecab-python is already installed
# Done.
# Processing /tmp/mecab-python-0.996
# Building wheels for collected packages: mecab-python
#   Building wheel for mecab-python (setup.py): started
#   Building wheel for mecab-python (setup.py): finished with status 'done'
#   Created wheel for mecab-python: filename=mecab_python-0.996_ko_0.9.2-cp37-cp37m-linux_x86_64.whl size=141821 sha256=2fc4974526cdd4ffa383f5dc29df342872b59dae1496324ed420ba78b6983cc3
#   Stored in directory: /root/.cache/pip/wheels/40/7b/9f/2922869bef86c3354ae7034f7a3647c573ee1997c2dad0290a
# Failed to build mecab-python
# Installing collected packages: mecab-python
#   Attempting uninstall: mecab-python
#     Found existing installation: mecab-python 0.996-ko-0.9.2
#     Uninstalling mecab-python-0.996-ko-0.9.2:
#       Successfully uninstalled mecab-python-0.996-ko-0.9.2
#     Running setup.py install for mecab-python: started
#     Running setup.py install for mecab-python: finished with status 'done'
# Successfully installed mecab-python-0.996-ko-0.9.2
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
#   WARNING: Built wheel for mecab-python is invalid: Metadata 1.2 mandates PEP 440 version, but '0.996-ko-0.9.2' is not
#   DEPRECATION: mecab-python was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.

# %%
import pandas as pd

train_df = pd.read_csv('./nsmc/ratings_train.txt', sep='\t')
test_df = pd.read_csv('./nsmc/ratings_test.txt', sep='\t')
train_df.dropna(inplace=True)
test_df.dropna(inplace=True)

# %%
import nltk
nltk.download('all')

# %%
# 구둣점 제거 -> 공백으로 대체
train_df['document'] = train_df['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣a-zA-Z0-9]"," ")

# %%
from nltk.tokenize import word_tokenize

train_text = []
test_text = []

stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

for text in train_df['document'][:8000]:
  temp = word_tokenize(text)
  no_stopwords_ver = [word for word in temp if not word in stopwords]
  train_text.append(no_stopwords_ver)
for text in test_df['document'][8000:9000]:
  temp = word_tokenize(text)
  no_stopwords_ver = [word for word in temp if not word in stopwords]
  test_text.append(no_stopwords_ver)
train_label = train_df['label'][:8000]
test_label = test_df['label'][8000:9000]

# %%
train_text[:5]
# Out:
# [['아', '더빙', '진짜', '짜증나네요', '목소리'],
#  ['흠', '포스터보고', '초딩영화줄', '오버연기조차', '가볍지', '않구나'],
#  ['너무재밓었다그래서보는것을추천한다'],
#  ['교도소', '이야기구먼', '솔직히', '재미는', '없다', '평점', '조정'],
#  ['사이몬페그의',
#   '익살스런',
#   '연기가',
#   '돋보였던',
#   '영화',
#   '스파이더맨에서',
#   '늙어보이기만',
#   '했던',
#   '커스틴',
#   '던스트가',
#   '너무나도',
#   '이뻐보였다']]

# %%
# # 토큰화

# from nltk.tokenize import word_tokenize
# from konlpy.tag import Kkma, Okt
# from konlpy.tag import Okt
# from tqdm import tqdm

# stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# train_text = []
# test_text = []

# okt = Okt()

# for text in tqdm(train_df['document']):
#   temp = okt.morphs("안녕하세요", stem=True)
#   no_stopwords_ver = [word for word in temp if not word in stopwords]
#   train_text.append(no_stopwords_ver)
# for text in tqdm(test_df['document']):
#   temp = okt.morphs(text, stem=True)
#   no_stopwords_ver = [word for word in temp if not word in stopwords]
#   test_text.append(no_stopwords_ver)
# train_label = train_df['label'][:8000]
# test_label = test_df['label'][8000:9000]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

def identity_tokenizer(text):
    return text

vetorizer = CountVectorizer(tokenizer=identity_tokenizer, lowercase=False)    
x_train = vetorizer.fit_transform(train_text)
x_test = vetorizer.transform(test_text)

# %%
data = data.toarray()

# %%
data

# %%
feature_names = tfidf_vetorizer.get_feature_names()
print(feature_names)
print(data)
# Out:
# ['!', '%', '&', "'", "''", "'드래곤'이란", "'라고", "'명작", "'신소율'씨", "'아", "'억지로", "'재현'해낸", "'하와이'에서의", '(', ')', '*', ',', ',기억에', ',영화', '-', '--', '-0-', '-ㅅ-', '.', '..', '...', '..ㅜㅜㅜㅜ', '..네이버', '..지나도그때의', './///', '.1점도아까움', '.ㅠ', '.그러나', '.나도', '.노답임', '.디카프리오', '.암튼', '.어차피', '.요즘', '.요즘은', '.울지', '.이', '.이딴영화', '.재미있음', '.전혀', '.정말노답', '.초딩들만', '.특히', '/./', '0.2정도', '0.5깎음', '007', '0점은', '1', '100분짜리', '100점', '10~20대', '10년', '10년동안에도', '10년이', '10억은', '10자이상', '10점', '10점씩', '10점으로도', '10점이다', '10점준', '10점줌', '12345678910', '13세', '13점~', '15년전', '15분짜리', '15세관람가라고', '18', '18..', '1914년작', '1982년', '1988년도', '1995년은', '1999년작', '19세', '1년', '1도', '1등', '1백만', '1백만을', '1빠의힘이', '1위', '1인', '1점', '1점도', '1점도아깝다', '1점주고', '1점주기도아까운', '1점줍니다', '1주기도', '1톤ㅋㅋ', '1편', '1편보다', '1편보단', '1편은', '1편을', '2,4인데..같은', '2.5', '2008년도에', '2010년에', '20대', '20대와', '24', '26년이', '26세', '2개', '2년만에', '2보다', '2시간', '2시간이', '2억5천인데', '2점', '2탄', '2탄까지', '2편', '2편에', '2편에서', '2편은', '2편을', '2편이', '2회하면', '3', '300이다', '3D연습으로', '3D영화입니다..원래', '3D작업을', '3가', '3개월이', '3등', '3류배우', '3백만', '3이', '3일간', '3일만에정말재밌게', '3점', '3탄도빨리나와라ㅠㅠ', '3편', '4', '40명', '40자', '4를', '4점', '5', '50년이훨씬지났지만', '5백만을', '5번이나', '5살짜리가', '5점대는', '5점부터', '5프로', '5형제', '6.9점ㅡㅡ', '6점정도가', '7', '70mm', '70년대', '77년도작', '7살', '7점은', '8.4', '80년대', '82년에', '84분동안', '85분동안', '8~10점준것들은', '8점', '8점까지는', '8점대는', '8점대이길래', '90년대', '90년대에', '97분', '9점', '9점이라면', ':', ';', '<', '>', '?', '@', 'AV나', 'A급이라', 'Best', 'Best_', 'B급', 'CG효과가', 'Carnahan의', 'Clayton', 'Concerto', 'D급', 'Emmanouella', 'Hikaru', 'I', 'I가', 'JFK를', 'Joe', 'Mavri', 'Merry', 'M창이', 'M창있네', 'No', 'OO', 'OOO', 'OOO기', 'OOO기막장영화', 'OO로', 'OO자식들인가', 'OO전', 'OST', 'OST도', 'OST타이틀곡도', 'Of', 'Ost와', 'PC통신', 'Piano', 'Rachmaninoff', 'SF', 'SF보다', 'SNS의', 'Shine', 'TV보다', 'TV사랑과전쟁', 'TV조선', 'USB에', 'Wakana', 'X같았습니다', 'Yes', '[', ']', '^^', '_', '_//', '``', 'asd', 'bad', 'bestest', 'cg처리보다', 'cliche', 'good', 'gt와', 'lsyandeugene', 'lt겨울나그네', 'naver.com으로', 'ok', 'ost와', 'shit', 'too', 'tv', 'tv판', 'tv프로예요', 'x친', '~', '~~~', '~~~~~~~~~~', '★', '♡', '♥', '♥예수님사랑해요오오오오', 'ㄱㅊ녀들이', 'ㄷㄷ', 'ㄷㄷㄷ', 'ㅂㅅ', 'ㅅㅂ', 'ㅅㅂ쓰레기', 'ㅇㄴ라머ㅣㅇ', 'ㅈ', 'ㅈㄴ착함', 'ㅈ씹노잼인데', 'ㅉㅉ', 'ㅉㅉ..', 'ㅋ', 'ㅋㅋ', 'ㅋㅋocn에서해주는거', 'ㅋㅋㅋ', 'ㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅅㅂ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ주먹질은', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ평점보고웃어본적은또첨이네', 'ㅋㅋㅋ별깤기잼', 'ㅋㅋㅋ지들만', 'ㅋㅋㅎㅎ음악이랑', 'ㅋㅋ내', 'ㅋㅋ역시나', 'ㅋㅋ이재희는', 'ㅋ스킨스미셸새아빠나온다신기하다', 'ㅎ', 'ㅎㅎ', 'ㅎㅎ~~~', 'ㅎㅎㅎ', 'ㅎㅎㅎ난디게재밌게봤는데가제트엄청귀여웠음', 'ㅎㅎ제발', 'ㅐ밌었어요~~', 'ㅑ', 'ㅜ', 'ㅜㅜ', 'ㅜㅠ', 'ㅜㅠㅠ', 'ㅜ재밋네요', 'ㅠ', 'ㅠ.ㅠ', 'ㅠ.ㅠ피노키오를', 'ㅠㅠ', 'ㅠㅠㅠ', 'ㅠㅠㅠㅠ소장하고싶은드라마', 'ㅡ', 'ㅡㅡ', 'ㅡㅡ^', 'ㅡㅡ이게뭐야', '가게에서', '가고싶은', '가까워서', '가끔', '가나다라마바사아사차카타파하', '가느니', '가는줄', '가능한', '가능할지', '가두는', '가득하다', '가라다', '가루로', '가만히', '가면', '가볍게', '가보라면', '가비얍게', '가서', '가수', '가슴', '가슴뭉클한', '가슴아팠고', '가슴에', '가슴으로', '가슴이', '가슴저리게', '가슴저리고', '가장', '가져다가', '가족드라마인가', '가족애니인듯ㅎ', '가족애를', '가족용', '가족의', '가족이니', '가족이랑', '가족중에', '가지', '가지게', '가지고', '가지고있는', '가지못한다', '가치가', '가치도', '가치로는', '가치없다', '가치있는일이다', '가해자', '각', '각각에게..', '각도에서', '각목으로', '각본과', '각색도', '각자의', '각주', '각하가', '간과했음', '간다', '간다는걸', '간단한게', '간츠는', '갈', '갈등하게', '갈등하는', '갈수록', '감독', '감독과', '감독님', '감독님^_ㅜ', '감독들이', '감독은', '감독을', '감독의', '감독이', '감독이었구나', '감독이었더라ㅡㅡ', '감독한테', '감독해서', '감동', '감동20', '감동ㅠ다시보는데', '감동과', '감동까지', '감동도', '감동도없고', '감동없는', '감동은', '감동을', '감동을주는좋은프로', '감동의', '감동이여서', '감동있는따뜻한영화..^^', '감동적', '감동적이고', '감동적이다', '감동적인', '감동적입니다', '감벽의', '감사드립니다', '감사함을', '감사합니다', '감상하였습니다', '감성', '감소한', '감시한', '감옥소재', '감을', '감점은', '감정과', '감정상태가', '감정이', '감정이입이', '감흥없음', '갑자기', '갔을텐데', '강기화씨의', '강도가', '강력한', '강렬함', '강렬했던', '강북고', '강신일이', '강예빈씨의노출로', '강인', '강추', '강추..진짜재밌습니다', '강하게', '같고', '같긴', '같냐', '같네', '같네요', '같네요.러닝타임', '같다', '같다..히키코모리인채로..이런', '같다.원작만이', '같습니다', '같아서', '같아영', '같아요', '같았다', '같았던', '같은', '같을줄알았는데..', '같음', '같음이번에도', '같이', '같잖지도', '같지만', '갚아야함은', '개', '개같은', '개노답', '개병맛', '개봉안하나', '개봉예정영화에', '개봉좀해주세요', '개봉하던', '개봉한지', '개봉할때', '개봉해도', '개봉해서', '개 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-acc2375b8ac6> in <module>()
#       1 feature_names = tfidf_vetorizer.get_feature_names()
#       2 print(feature_names)
# ----> 3 print(data)
#
# NameError: name 'data' is not defined

# %%
# x_train = train_text
# x_test = test_text
y_train = train_label
y_test = test_label

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
clf = MultinomialNB(alpha=.01)
clf.fit(x_train, y_train)
pred = clf.predict(x_test)
print('F1 =', metrics.f1_score(y_test, pred, average='macro'))
print('accuracy =', metrics.accuracy_score(y_test, pred))
# Out:
# F1 = 0.729476266051075
# accuracy = 0.73
